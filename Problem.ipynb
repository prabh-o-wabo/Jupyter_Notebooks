# %%
import numpy as np

# %%
trials = 100_000

days = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']

# %%
same_day = 0
for _ in range(trials):
    alan_day = np.random.choice(days)
    betty_day = np.random.choice(days)
    same_day += 1 if alan_day == betty_day else 0

print(f'{same_day / trials = }')
# Out:
# same_day / trials = 0.14201

# %%
from itertools import permutations
import random

vowels = 'aeiou'

RESCUE = 'RESCUE'
anagrams = {''.join(p).lower() for p in permutations(RESCUE)}
print(f'{len(anagrams)} unique anagrams')
# Out:
# 360 unique anagrams
